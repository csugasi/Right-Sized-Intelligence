# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.3/616.3 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 49.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 124.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [datasets]7/8 [datasets]ce-hub]
# ...

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("open-llm-leaderboard/contents")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4576 [00:00<?, ? examples/s]

# %%
# Size of the dataset
#len(ds['train'])
print(f"Shape of the dataset:{ds['train'].shape}")
# Out:
# Shape of the dataset:(4576, 36)

# %%
df = ds['train'].to_pandas() # only one slipt available in the dataset -'train'
df.to_csv("203-Final_Project/open_llm_leaderboard.csv", index = False)
